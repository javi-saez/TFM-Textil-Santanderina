# %%
import pandas as pd
import openpyxl
import xlrd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
tablas20_1 = glob.glob("C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/2015*.xlsx")
tablas20_2 = glob.glob("C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/2016*.xlsx")
tablas20_3 = glob.glob("C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/2017*.xlsx")
tablas20_4 = glob.glob("C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/2018*.xlsx")
tablas20_5 = glob.glob("C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/2019*.xlsx")
tablas20_all = list([tablas20_1,tablas20_2,tablas20_3, tablas20_4, tablas20_5])

# %%
pmf_group1 = np.empty(0)
empty_array = np.empty(0)


for year in tablas20_all:
    for data in year:
        df = pd.read_excel(data, engine='openpyxl')
        df_f = df.loc[df['TipoDoc'].isin(['F'])]
        fm = empty_array
        df_g = df_f.loc[df_f['GrupoArticulo'].isin([1])]
        fm = np.append(fm,df_g['Importe'])
        pmf_group1 = np.append(pmf_group1, fm.sum())

# %%
months = np.arange(1,13)
months = np.tile(months,reps=5)

# %%
df_group1 = pd.DataFrame({'months': months, 'total_sells_per_month_group_1': pmf_group1})

# %%
df_group1
# Out:
#     months  total_sells_per_month_group_1
# 0        1                   1.333316e+08
# 1        2                   1.370845e+08
# 2        3                   2.957363e+08
# 3        4                   2.195312e+08
# 4        5                   1.765422e+08
# 5        6                   2.161052e+08
# 6        7                   2.337620e+08
# 7        8                   9.788699e+07
# 8        9                   2.605413e+08
# 9       10                   1.743063e+08
# 10      11                   2.310997e+08
# 11      12                   2.071762e+08
# 12       1                   2.456453e+08
# 13       2                   4.707599e+08
# 14       3                   4.325603e+08
# 15       4                   1.287202e+08
# 16       5                   1.545949e+08
# 17       6                   1.107688e+08
# 18       7                   1.536606e+08
# 19       8                   6.276984e+07
# 20       9                   7.861154e+07
# ...

# %%
df_group1.total_sells_per_month_group_1.hist()
# Out:
# <AxesSubplot:>

# %%
df_group1.total_sells_per_month_group_1.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df_group1.total_sells_per_month_group_1
y = y.values.reshape(-1,1)
y.shape
# Out:
# (60, 1)

# %%
x = df_group1.months
x = x.values.reshape(-1,1)
x.shape
# Out:
# (60, 1)

# %%
model = LinearRegression().fit(x,y)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.20330908378357238

# %%
df_group1.to_pickle("pmf_group1.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0e7e6f28ad4c> in <module>
# ----> 1 df_group1.to_pickle("pmf_group1.pkl")
#
# NameError: name 'df_group1' is not defined

# %%
data = pd.read_excel('C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/ejemplo_datos.xlsx', engine='openpyxl')

# %%
df_group1 = pd.DataFrame(index=[], columns=data.columns)

for year in tablas20_all:
    for month in year:
        df = pd.read_excel(month, engine='openpyxl')
        df_f = df.loc[df['TipoDoc'].isin(['F'])]
        df_g1 = df_f.loc[df_f['GrupoArticulo'].isin([1])]
        df_group1 =  df_group1.append(df_g1, ignore_index=True)
        print("esto funciona")
# Out:
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona

# %%
df_group1
# Out:
#        TipoDoc Documento LineaDoc Factura LineaFra                    Fecha  \
# 0            F    580599        1  580599        1  2015-01-01 00:00:00.000
# 1            F    580599        2  580599        2  2015-01-01 00:00:00.000
# 2            F    580599        3  580599        3  2015-01-01 00:00:00.000
# 3            F    580599        4  580599        4  2015-01-01 00:00:00.000
# 4            F    580599        6  580599        6  2015-01-01 00:00:00.000
# ...        ...       ...      ...     ...      ...                      ...
# 258886       F    656691        2  656691        2  2019-12-31 00:00:00.000
# 258887       F    656691        3  656691        3  2019-12-31 00:00:00.000
# 258888       F    656691        3  656691        3  2019-12-31 00:00:00.000
# 258889       F    656691        4  656691        4  2019-12-31 00:00:00.000
# 258890       F    656691        5  656691        5  2019-12-31 00:00:00.000
#
# ...

# %%
(unicos, cuenta) = np.unique(df_group1.CodigoArticulo, return_counts=True)

# %%
(unicos, cuenta)
# Out:
# (array([2788, 5988, 5997, ..., 166623, 166632, 166715], dtype=object),
#  array([   1, 3337,   87, ...,   16,   40,   24], dtype=int64))

# %%
df_tipodeproducto = pd.DataFrame({'tipos_producto':unicos, 'frequencia': cuenta})

# %%
df_tipodeproducto.sort_values('frequencia',ascending=False ).iloc[0:47,:]
# Out:
#      tipos_producto  frequencia
# 145          106594       68334
# 135          105454       33860
# 501          120440       13137
# 8             23422       12343
# 23            52211        6400
# 51            84386        5287
# 42            78893        5170
# 46            81711        4944
# 15            33673        4302
# 236          111258        3569
# 1              5988        3337
# 47            82735        2823
# 480          120094        2486
# 18            48931        2325
# 652          125153        2206
# 6             23362        2126
# 19            48932        2005
# 339          115811        1958
# 241          111601        1877
# 363          116976        1858
# 474          119956        1690
# 553          121511        1494
# 672          126898        1452
# 189          109323        1391
# 673          126899        1365
# 360          116970        1330
# 239          111391        1255
# 625          123881        1128
# ...

# %%
df_tipodeproducto.sort_values('frequencia',ascending=False ).iloc[0:47,:].sum()
# Out:
# tipos_producto    4650224
# frequencia         207405
# dtype: int64

# %%
df_quality_g1 = pd.DataFrame(index=[], columns=data.columns)

for year in tablas20_all:
    for month in year:
        df = pd.read_excel(month, engine='openpyxl')
        df_a = df.loc[df['TipoDoc'].isin(['A'])]
        df_g1 = df_a.loc[df_a['GrupoArticulo'].isin([1])]
#         df_g1 = df_g1.loc[df_g1['TipoOperacion'].isin(['Producto Defectuoso           ',])]
        df_quality_g1 =  df_quality_g1.append(df_g1, ignore_index=True)
        print("esto funciona")
# Out:
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona

# %%
df_quality_g1
# Out:
#       TipoDoc Documento LineaDoc Factura LineaFra                    Fecha  \
# 0           A     66472        1  580655        1  2015-01-12 00:00:00.000
# 1           A     66472        2  580655        2  2015-01-12 00:00:00.000
# 2           A     66434        1  564828        1  2015-01-14 00:00:00.000
# 3           A     66434        1  564828        1  2015-01-14 00:00:00.000
# 4           A     66434        1  564828        1  2015-01-14 00:00:00.000
# ...       ...       ...      ...     ...      ...                      ...
# 17776       A     73789        1  655939        1  2019-12-19 00:00:00.000
# 17777       A     73789        1  655939        1  2019-12-19 00:00:00.000
# 17778       A     73789        1  655939        1  2019-12-19 00:00:00.000
# 17779       A     73789        1  655939        1  2019-12-19 00:00:00.000
# 17780       A     73789        1  655939        1  2019-12-19 00:00:00.000
#
# ...

# %%
df_quality_g1.TipoOperacion.unique()
# Out:
# array(['Cambios                       ', 'Devol.Mercanc.Defectos',
#        'Muestras', 'Devolución de Mercancía       ', 'Exceso Mercancía',
#        'Retraso Servicio', 'Producto Defectuoso           ',
#        'Ajuste de Precio              ', 'Ajuste de Cantidad            ',
#        'Prendas Defectuosas', 'Devol.Mercanc.Exceso',
#        'Devol.Mercanc.Retraso'], dtype=object)

# %%
df_quality_g1 = pd.DataFrame(index=[], columns=data.columns)

for year in tablas20_all:
    for month in year:
        df = pd.read_excel(month, engine='openpyxl')
        df_a = df.loc[df['TipoDoc'].isin(['A'])]
        df_g1 = df_a.loc[df_a['GrupoArticulo'].isin([1])]
        df_g1 = df_g1.loc[df_g1['TipoOperacion'].isin(['Producto Defectuoso           ','Prendas Defectuosas','Devol.Mercanc.Defectos'])]
        df_quality_g1 =  df_quality_g1.append(df_g1, ignore_index=True)
        print("esto funciona")
# Out:
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona

# %%
df_quality_g1
# Out:
#      TipoDoc Documento LineaDoc Factura LineaFra                    Fecha  \
# 0          A     66507        1  572114        1  2015-01-21 00:00:00.000
# 1          A     66507        1  572114        1  2015-01-21 00:00:00.000
# 2          A     66507        1  572114        1  2015-01-21 00:00:00.000
# 3          A     66507        1  572114        1  2015-01-21 00:00:00.000
# 4          A     66507        1  572114        1  2015-01-21 00:00:00.000
# ...      ...       ...      ...     ...      ...                      ...
# 8351       A     73788        1  655569        1  2019-12-19 00:00:00.000
# 8352       A     73788        1  655569        1  2019-12-19 00:00:00.000
# 8353       A     73788        1  655569        1  2019-12-19 00:00:00.000
# 8354       A     73788        1  655569        1  2019-12-19 00:00:00.000
# 8355       A     73788        1  655569        1  2019-12-19 00:00:00.000
#
#      Cliente PaisCliente PaisDestino Departamento  ... Combinacion Color  \
# ...

# %%
(unicos, cuenta) = np.unique(df_quality_g1.CodigoArticulo, return_counts=True)

# %%
#we store the generated dataframes
df_group1.to_pickle('df_group1.pkl')

# %%
df_quality_g1.to_pickle('df_quality_g1.pkl')

# %%
df_tipodeproducto.to_pickle('df_tipodeproducto.pkl')

# %%
pma_group1 = np.empty(0)
empty_array = np.empty(0)


for year in tablas20_all:
    for data in year:
        df = pd.read_excel(data, engine='openpyxl')
        df_a = df.loc[df['TipoDoc'].isin(['A'])]
        am = empty_array
        df_g = df_a.loc[df_a['GrupoArticulo'].isin([1])]
        am = np.append(am,df_g['Importe'])
        pma_group1 = np.append(pma_group1, am.sum())

# %%
abs(pma_group1)
# Out:
# array([1.72480549e+07, 6.74733925e+06, 1.32400684e+07, 3.06668463e+06,
#        4.24118340e+05, 3.16800070e+05, 1.21152859e+06, 2.28798900e+04,
#        1.12765500e+05, 1.63478969e+07, 2.59943909e+06, 8.89612540e+05,
#        8.35339270e+05, 4.59928085e+06, 2.57943879e+06, 8.13952320e+05,
#        2.15442510e+05, 2.99730230e+05, 4.22441900e+04, 3.29597440e+05,
#        3.60972000e+03, 3.54368865e+06, 6.20360410e+05, 1.58130210e+05,
#        3.50187600e+05, 2.95122690e+05, 3.64213967e+07, 1.72156565e+06,
#        1.09771170e+05, 1.05813588e+06, 5.77190000e+02, 0.00000000e+00,
#        1.25782570e+05, 3.34338080e+06, 2.08350464e+06, 1.39476373e+06,
#        1.54506251e+06, 2.86779485e+06, 5.27229420e+06, 8.73878762e+07,
#        2.65095370e+05, 6.11848210e+05, 5.44990110e+05, 1.30955500e+04,
#        3.68667496e+06, 1.20860100e+04, 2.91559350e+05, 2.35875013e+06,
#        3.86295000e+03, 3.61478690e+05, 2.68995680e+05, 1.73439254e+07,
# ...

# %%
pma_group1
# Out:
# array([-1.72480549e+07, -6.74733925e+06, -1.32400684e+07, -3.06668463e+06,
#        -4.24118340e+05, -3.16800070e+05, -1.21152859e+06, -2.28798900e+04,
#        -1.12765500e+05, -1.63478969e+07, -2.59943909e+06, -8.89612540e+05,
#        -8.35339270e+05, -4.59928085e+06, -2.57943879e+06, -8.13952320e+05,
#        -2.15442510e+05, -2.99730230e+05, -4.22441900e+04, -3.29597440e+05,
#        -3.60972000e+03, -3.54368865e+06, -6.20360410e+05, -1.58130210e+05,
#        -3.50187600e+05, -2.95122690e+05, -3.64213967e+07, -1.72156565e+06,
#        -1.09771170e+05, -1.05813588e+06, -5.77190000e+02,  0.00000000e+00,
#        -1.25782570e+05, -3.34338080e+06, -2.08350464e+06, -1.39476373e+06,
#        -1.54506251e+06, -2.86779485e+06, -5.27229420e+06, -8.73878762e+07,
#        -2.65095370e+05, -6.11848210e+05, -5.44990110e+05, -1.30955500e+04,
#        -3.68667496e+06, -1.20860100e+04, -2.91559350e+05, -2.35875013e+06,
# ...

# %%
pmf_group1 = pd.read_pickle("pmf_group1.pkl")

# %%
months_group1 = pd.DataFrame({'months':months, 'total_sells':pmf_group1.total_sells_per_month_group_1,
                              'total_refunds':abs(pma_group1),'refunds_vs_sells_ratio':abs(pma_group1)/pmf_group1.total_sells_per_month_group_1})

# %%
months_group1
# Out:
#     months   total_sells  total_refunds  refunds_vs_sells_ratio
# 0        1  1.333316e+08    17248054.95                0.129362
# 1        2  1.370845e+08     6747339.25                0.049220
# 2        3  2.957363e+08    13240068.36                0.044770
# 3        4  2.195312e+08     3066684.63                0.013969
# 4        5  1.765422e+08      424118.34                0.002402
# 5        6  2.161052e+08      316800.07                0.001466
# 6        7  2.337620e+08     1211528.59                0.005183
# 7        8  9.788699e+07       22879.89                0.000234
# 8        9  2.605413e+08      112765.50                0.000433
# 9       10  1.743063e+08    16347896.90                0.093788
# 10      11  2.310997e+08     2599439.09                0.011248
# 11      12  2.071762e+08      889612.54                0.004294
# 12       1  2.456453e+08      835339.27                0.003401
# 13       2  4.707599e+08     4599280.85                0.009770
# ...

# %%
months_group1.to_pickle("df_months_group1.pkl")
