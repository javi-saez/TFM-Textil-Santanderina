# %%
import pandas as pd
import openpyxl
import xlrd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/ejemplo_datos.xlsx', engine='openpyxl')

# %%
data.columns
# Out:
# Index(['TipoDoc', 'Documento', 'LineaDoc', 'Factura', 'LineaFra', 'Fecha',
#        'Cliente', 'PaisCliente', 'PaisDestino', 'Departamento',
#        'TipoOperacion', 'AfectaCantidad', 'Cantidad', 'Unidad', 'Precio',
#        'Moneda', 'Cambio', 'Importe', 'CodigoArticulo', 'GrupoArticulo',
#        'Serie', 'Acabado', 'Estampado', 'Combinacion', 'Color', 'Ancho', 'CN8',
#        'Composicion', 'Lote', 'Pieza', 'MetroPieza', 'MetrosReducidos',
#        'MetrosDefectuosos'],
#       dtype='object')

# %%
df_refunds = pd.DataFrame(index=[], columns=data.columns)

# %%
tablas20_ = glob.glob("C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/2016*.xlsx")
df_refunds = pd.DataFrame(columns=data.columns)
# df_bills = pd.DataFrame(columns=data.columns)
for f in tablas20_:
    df = pd.read_excel(f, engine='openpyxl')
    df_a = df.loc[df['TipoDoc'].isin(['A'])]
#     df_f = df.loc[df['TipoDoc'].isin(['F'])]
    df_refunds =  df_refunds.append(df_a, ignore_index=True)
#     df_bills = df_refunds.append(df_f, ignore_index=True)
    print("esto funciona")
# Out:
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona
# esto funciona

# %%
df_refunds
# Out:
#       TipoDoc Documento LineaDoc Factura LineaFra                    Fecha  \
# 0           A     68222        1  595424        1  2016-01-13 00:00:00.000
# 1           A     68222        2  595424        2  2016-01-13 00:00:00.000
# 2           A     68222        3  595424        3  2016-01-13 00:00:00.000
# 3           A     68222        4  595424        4  2016-01-13 00:00:00.000
# 4           A     68223        1  596590        1  2016-01-13 00:00:00.000
# ...       ...       ...      ...     ...      ...                      ...
# 15160       A     69735        1  604197        1  2016-12-31 00:00:00.000
# 15161       A     69735        1  604197        1  2016-12-31 00:00:00.000
# 15162       A     69735        1  604197        1  2016-12-31 00:00:00.000
# 15163       A     69735        1  604197        1  2016-12-31 00:00:00.000
# 15164       A     69736        1  610102        1  2016-12-31 00:00:00.000
#
# ...

# %%
list_of_documents = list(df_refunds['Factura'])
df_cr = pd.DataFrame(columns=data.columns)
tablas20_ = glob.glob("C:/Users/Javier/Documents/GIT/Repositories/TFM-Textil-Santanderina/data/raw/2015*.xlsx")


for f in tablas20_:
    df = pd.read_excel(f, engine='openpyxl')
    df_refunded_bills = df.loc[df['TipoDoc'].isin(list_of_documents)]
    df_cr =  df_cr.append(df_refunded_bills, ignore_index=True)
    print(df_cr.shape)
# Out:
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
# (0, 33)
